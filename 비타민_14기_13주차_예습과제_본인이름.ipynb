# %% [markdown]
# # **5조**
# ## **학습관련 기술(매개변수 갱신, 가중치 초깃값)**

# %% [markdown]
# ## **1.매개변수 갱신** (32점)
# 지난 세션에서 손실함수와 각 가중치(w) 간의 기울기를 구하는 방법을 배웠습니다. 또한 손실함수 값, 즉 Loss값은 모델의 예측값과 정답 간의 오차입니다. 따라서 Loss값이 클수록 모델의 성능이 떨어진다고 평가할 수 있습니다.
#
# 그렇다면 자연스럽게 어떻게 Loss값을 줄일 수 있을지 고민해봐야 합니다. 그에 대한 해답은 아래의 이야기를 통해서 알 수 있습니다.
#
# ---
#
# 밑바닥부터 시작하는 딥러닝 발췌
#
#  색다른 모험가가 있스빈다. 광할한 메마른 산맥을 여행하면서 날마다 깊은 골짜기를 찾아 발걸음을 옮깁니다. 그는 전설에 나오는 세상에서 가장 깊고 낮은 골짜기, “깊은 곳”을 찾아가려 합니다. 그것이 그의 목적이죠. 게다가 그는 엄격한 “제약” 2개로 자신을 옭아맸습니다. 하나는 지도를 보지 않을 것, 또 하나는 눈가리개를 쓰는 것입니다. 지도도 없고 보이지도 않으니 가장 낮은 골까지가 광대한 땅 어디에 있는지 알 도리가 없죠. 그런 혹독한 조건에서 이 모험가는 어떻게 “깊은 곳”을 찾을 수 있을까요? 어떻게 걸음을 옮겨야 효율적으로 찾아낼 수 있을까요?
#
#  이 어려운 상황에서 중요한 단서가 되는 것이 땅의 ‘기울기’입니다 모험가는 주위 경치는 볼 수 없지만 지금 서 있는 땅의 기울기는 알 수 있습니다. 발바닥으로 전해지죠. 그래서 지금 서 있는 장소에서 가장 크게 기울어진 방향으로 가자는 것이 SGD의 전략입니다. 이 일을 반복하면 언젠가 ‘깊은 곳’에 찾아갈 수 있을지도 모르죠.
#
#  우리는 Loss라는 산 속에서 가장 낮은 곳(최솟값, 좋은 성능)으로 가기 위해 Loss값(손실함수값)과 각 변수의 기울기(땅의 기울기)를 구한 것입니다.

# %% [markdown]
# ### 문제1. 다음 중 매개변수 갱신방법으로 아닌 것을 고르시오. (2점)
#
# a) Adam
#
# b) Momentum
#
# c) Gradient
#
# c) SGD

# %% [markdown]
# ### 정답 : c

# %% [markdown]
# ### 문제2 . 다음 문장의 True, False를 판별하시오.(2점)
#
# 1) SGD는 각 파라미터에 대해 적응적으로 학습률을 조정한다.
#
# 2) Momentum은 그래디언트에 대한 과거의 업데이트 방향을 고려하여 관성을 추가한다.
#
# 3) Adagrad는 학습이 진행될수록 학습률이 점차 증가하여, 최적화 속도가 빨라진다.
#
# 4) Adam 옵티마이저는 Adagrad와 Momentum의 장점을 결합한 알고리즘이다.

# %% [markdown]
#  정답 :
#
# a) False
#
# b) True
#
# c) False
#
# d) True

# %% [markdown]
# ### 문제3. SGD의 약자를 작성하시고, S의 의미를 포함하여 SGD에 대해 간단하게 설명하시오. (4점)

# %% [markdown]
# 정답 :
#
#  SGD의 약자 : Stochastic Gradient Descent
#
#  SGD의 의미 : 전체 데이터 셋에서 확률적으로 추출된 소규모 데이터를 사용하여 기울기를 계산하고 손실함수 기울기를 따라 최적의 파라미터를 찾는 알고리즘.

# %% [markdown]
# ### 문제4. 자료는 SGD의 가중치 업데이트 모습입니다. 자료를 통해 알 수 있는 SGD의 한계에 대해 서술하시오.(3점)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  정답 : 매번 랜덤배치를 사용해 진동이 발생하고 수렴이 느려진다. 최적점에서 정확도가 감소한다.

# %% [markdown]
# ### 문제5. 다음 중 Momentum 옵티마이저에 대한 설명으로 옳지 않은 것은? (3점)
#
# 1) 그래디언트 업데이트에 과거의 이동 평균을 반영하여 관성을 추가한다.
#
# 2) 진동을 줄이고 최적화 경로를 더 안정적으로 만드는 데 도움을 준다.
#
# 3) 학습률이 학습 과정에서 자동으로 감소하도록 설계되어 있다.
#
# 4) SGD의 단점을 보완하기 위해 그래디언트의 방향성을 더 강조한다.

# %% [markdown]
#  정답 : 3

# %% [markdown]
# ### 문제6. 아래는 모멘텀 방식을 표현한 수식입니다. 각 변수의 의미를 서술하시오.(5점)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  정답 :
#
#  v : 모멘텀 업데이트값
#
# a : 관성계수
#
# η: 학습률
#
# ∂W/∂L : 손실함수에 대한 가중치 변화량
#
#  W : 가중치 파라미터

# %% [markdown]
#  Momentum은 그래디언트 값의 관성을 활용해 학습 방향을 조정하는 방법입니다. 그러나 신경망을 학습할 때는 모델 사용자가 조정해야 하는 중요한 변수가 하나 있습니다. 바로 학습률입니다. 이제, 학습률을 조정하여 신경망을 더욱 효율적으로 학습시키는 방법에 대해 알아보겠습니다.

# %% [markdown]
# ### 문제7. 앞서 제시된 자료처럼 기울기가 너무 급한 방향은 학습 속도가 너무 빠른 문제가, 기울기가 완만한 방향은 학습 속도가 너무 느린 문제점이 있었습니다. 이러한 문제점을 극복하기 위해 AdaGrad가 제시한 해결책, 즉 AdaGrad의 핵심아이디어를 서술하세요. (4점)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  정답 : 그레디언트 제곱값을 누적하여 학습률을 조정

# %% [markdown]
# ### 문제8. 안장점과 관련하여 AdaGrad의 한계에 대해 서술하시오. (3점)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  답 : AdaGrad는 학습률의 급격한 감소로 인해 조기 안정점(Local Minimum) 또는 Saddle Point에서 학습이 멈출 위험이 있음.

# %% [markdown]
# ### 문제9. 앞서 다룬 SGD와 Momentum  중 위 안장점으로 인한 문제를 해결할 수 있는 학습방법은? (2점)
#
# a) SGD
#
# b) Momentum

# %% [markdown]
#  정답 : b

# %% [markdown]
# ### 문제10. 다음은 Adam을 구현한 코드입니다. 빈칸에 들어갈 코드를 작성하시오. (4점)
# - 수식이 의미하는 바를 생각하며 작성해주세요!

# %%
import numpy as np

class AdamOptimizer:
    def __init__(self, params, lr=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):

        self.params = params
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon

        # Initialize moment estimates
        self.m = [np.zeros_like(p) for p in params]  # First moment
        self.v = [np.zeros_like(p) for p in params]  # Second moment
        self.t = 0  # Time step

    def step(self, gradients):

        self.t += 1

        for i, (param, grad) in enumerate(zip(self.params, gradients)):
            # Update biased first moment estimate
            self.m[i] = self.beta1 * self.m[i] + (1 - self.beta1) * grad

            # Update biased second moment estimate
            self.v[i] = self.beta2 * self.v[i] + (1 - self.beta2) * (grad ** 2)

            # Correct bias in moment estimates
            m_hat = self.m[i] / (1 - self.beta1 ** self.t)
            v_hat = self.v[i] / (1 - self.beta2 ** self.t)

            # Update parameters
            param -= self.lr * m_hat / (np.sqrt(v_hat) + self.epsilon)

# %% [markdown]
# 3# **2. 가중치 초기화** (18점)

# %% [markdown]
#  처음 모델을 불러올 때, 신경망 속 가중치는 임의로 부여됩니다. 하지만 가중치를 임의로 부여할 때도 어떤 방식으로 가중치를 지정하느냐에 따라 모델의 성능 차이가 발생합니다. 지금부터는 모델 속 가중치 초기값이 모델 성능에 어떤 영향을 끼치는지 알아보겠습니다.

# %% [markdown]
# ### 문제11. 다음 중 Xavier 초기화에 대한 설명으로 옳은 것은? (3점)
#
# 1) 모든 가중치를 0으로 초기화한다.
#
# 2) 가중치를 표준 정규분포에서 무작위로 초기화한다.
#
# 3) 입력 노드와 출력 노드의 개수를 고려하여 가중치를 초기화한다.
#
# 4) 가중치를 큰 값으로 초기화해 활성화 함수의 포화 문제를 방지한다.

# %% [markdown]
#  정답 : 3

# %% [markdown]
# ### 문제12. Xavier 초기화는 다음 중 어떤 활성화 함수와 함께 주로 사용되는가? (2점)
#
# 1) Sigmoid와 Tanh
#
# 2) ReLU와 Leaky ReLU
#
# 3) Softmax와 Sigmoid
#
# 4) None of the above

# %% [markdown]
#  정답 : 1

# %% [markdown]
# ### 문제13. 다음 문장의 True, False를 판별하시오. (3점)
#
# 1) 모델 초기 학습에서 가중치를 모두 0으로 만들어 과적합을 방지한다.
#
# 2) Xavier 초기화는 신경망의 층이 깊어질수록 그래디언트 소실 문제를 완전히 방지할 수 있다.

# %% [markdown]
# 정답 :
#
# 1) False
#
# 2) False

# %% [markdown]
# ### 문제14. 아래는 활성화함수로 sigmoid함수를 사용할 때, 각 레이어의 활성화함수 값의 분포이다. 각 레이어의 활성화 함수값이 어떤 값들을 많이 가지고 있는지 서술하시오.(4점)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제15. Xavier초깃값은 어떤 분포를 이용하여 가중치값을 임의결정하는지 작성하시오. (4점)

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제16. 활성화함수로 ReLU를 이용할 때, 적합한 가중치 초깃값 방식을 작성하시오. (2점)

# %% [markdown]
# 정답 :

# %% [markdown]
# # **1조**
# ##  **학습관련 기술(배치정규화, 하이퍼파라미터 최적화)**

# %% [markdown]
# ## 1. 배치정규화 & overfitting & 가중치 감소

# %% [markdown]
# ### 문제1. 다음 중 배치정규화에 대한 설명으로 옳지 않은 것을 고르세요. (4점)
#
# 1) 각 층이 활성화를 적당히 퍼뜨리도록 강제하는 것을 배치 정규화라고 한다.
#
# 2) 학습 속도가 개선된다.
#
# 3) 초기값에  크게 의존한다.
#
# 4) overfitting을 억제할 수 있다.
#
# 5) 배치 정규화는 학습시 미니배치를 단위로 정규화한다.

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제2. 아래의 ???를 채워 설명을 완성하세요. (4점)
#
# 데이터 분포가 평균이 ???, 분산이 ???이 되도록 정규화한다.

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제3. 아래의 overfitting에 대한 설명이 참인지 거짓인지(T/F) 순서대로 작성하세요. (4점, 한 문제당 1점)
#
# (1) 신경망이 훈련 데이터에만 지나치게 적응되어 그 외의 데이터에는 제대로 대응하지 못하는 상태 overfitting이라 한다. (T/F)
#
# (2) 기계학습은 범용 성능을 지향하기 때문에 overfitting을 억제하는 것이 중요하다. (T/F)
#
# (3) overfitting은 매개변수가 적고 표현력이 낮은 모델에서 주로 발생한다. (T/F)
#
# (4) overfitting은 훈련 데이터가 적을 경우 주로 발생한다. (T/F)

# %% [markdown]
#  정답 :
#  (1)
#
# (2)
#
# (3)
#
# (4)

# %% [markdown]
# ### 문제4. 아래의 ???을 채워 설명을 완성하세요. (4점)
#
# 학습 과정에서 큰 가중치에 대해서는 ??? 페널티를 부과하여 overfitting을 억제한다.

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제5. 아래의 ???을 채워 설명을 완성하세요. (4점)
#
# 기존 손실값 + (람다 $\lambda$값이 곱해진) 가중치의 절대값을 ??? 라고 한다.
#
# ![davkqnjb.png](data:image/png;base64,...)

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제6. 아래의 ???을 채워 설명을 완성하세요. (4점)
#
# 기존 손실값 + 가중치의 제곱값, 각 가중치(W)를 제곱한 것의 총합을 2로 나눠준 값을  ??? 라고 한다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 2. 드롭아웃 & 하이퍼파라미터 최적화

# %% [markdown]
# ### 문제7. 드롭아웃이 무엇인지 간단하게 설명하세요. (5점)

# %% [markdown]
# 정답 :

# %% [markdown]
# ###문제8. 다음 (a)와 (b) 중 무엇이 드롭아웃을 적용한 신경망인지 고르세요.(4점)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제9. 아래의 ???을 채워 설명을 완성하세요. (4점)
#
# - ??? 는 전체 트레이닝 셋이 신경망을 통과한 횟수를 의미한다.
# - ??? 은 1-epoch를 마치는데 필요한 미니배치 갯수 즉, 1-epoch를 마치는데 필요한 파라미터 업데이터 횟수를 의미한다.
# - 입력에 따른 기대 값과 실제 값의 차이를 계산하는 함수를 ???라고 한다.

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제10. 하이퍼파라미터의 성능을 평가할 때에는 시험 데이터를 사용하면 안되는 이유를 간략하게 서술하세요. (5점)

# %% [markdown]
# 정답 :

# %% [markdown]
# ### 문제11. 다음 중 네트워크 구조와 관련된 하이퍼 파라미터와 학습에 사용되는 하이퍼 파라미터를 매치하세요.(4점)
# (a) 은닉층의 뉴런 개수
#
# (b) 학습률(Learning rate)
#
# (c) 모멘텀 (momentum)
#
# (d) 에포크 (epoch, training epochs)
#
# (e) Dropout
#
# (f) 배치 사이즈 (batch size)
#
# (g) 가중치 초기화
#
# (h) 정규화 파라미터 (Regularization parameter)

# %% [markdown]
# 정답 :
# - 네트워크 구조와 관련된 하이퍼 파라미터 :
# - 학습에 사용되는 하이퍼 파라미터 :

# %% [markdown]
# ### 문제12. 다음중 Hyperparameter Tuning에 대한 설명으로 옳지 않은 것을 고르세요.
#  (4점)
#
# (1) Hyperparameter Tuning은 모델이나 데이터에 맞춰 여러 시도 후 모델이 맞는 하이퍼파라미터를 찾아 나가는 과정이다.
#
# (2) Manual Search은 경험 또는 감으로 하이퍼파라미터 값을 설정하는 방법다.
#
# (3) Bayesian Optimization은 가능한 모든 조합의 하이퍼파라미터로 훈련시켜서 최적의 조합을 찾는 방법이다.
#
# (4) Random Search은 경계 내에서 임의의 조합을 추출하여 최적의 조합을 찾는 방법이다.
#
# (5) Optuna는 하이퍼파라미터 최적화 태스크를 자동화해주는 프레임워크이다.

# %% [markdown]
# 정답 :
